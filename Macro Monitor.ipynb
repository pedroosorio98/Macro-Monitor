# %% [markdown]
# # <center> Macro Monitor </center>

# %% [markdown]
# - **Summary:** This notebook provides a macro monitor that can daily send e-mails with a PDF macro report. The report includes data only in an yearly frequency.
# $$
# $$
# - **Data Included in the Report:**
# $$
# $$
#     - BLS US Inflation data.
#     - World Equity Indices data.
#     - FX USD data.
#     - Commodities futures data.

# %% [markdown]
# ### Importing necessary modules:

# %%
import requests
import json
from functools import reduce
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import math
import fpdf
import pandas as pd
from PyPDF2 import PdfFileMerger, PdfFileReader
import dataframe_image
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import pandas_datareader as pdr

# %%
from socket import gethostname
from email.mime.application import MIMEApplication
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import smtplib
import json

# %% [markdown]
# ### US BLS Inflation Data:

# %%
series_names = {'CUSR0000SA0':'All items','CUSR0000SA0L1E':'All items less food and energy',
                'CUSR0000SAF1':'Food', 'CUSR0000SA0E':'Energy', 'CUSR0000SAA':'Apparel', 
                'CUSR0000SAE':'Education and communication','CUSR0000SAG':'Other goods and services',
               'CUSR0000SAM':'Medical care','CUSR0000SAR':'Recreation','CUSR0000SAT':'Transportation'}

# %%
id_list = ['CUSR0000SA0','CUSR0000SA0L1E','CUSR0000SAF1',
            'CUSR0000SA0E', 'CUSR0000SAA','CUSR0000SAE',
            'CUSR0000SAG','CUSR0000SAM','CUSR0000SAR',
            'CUSR0000SAT']

# %%
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": id_list,"startyear":"2014", "endyear":"2022"})

# %%
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)

# %% [markdown]
# **Constructing a list of dataframes with one dataframe for each series:**

# %%
data_list = [] # criando uma lista de dataframes
for series in json_data["Results"]["series"]:
    df = pd.DataFrame(series["data"]).drop(["footnotes","periodName","latest"],axis=1) # 
    df.rename(columns={"value":series_names[series["seriesID"]]}, inplace=True) # renomeando a coluna do dataframe
    data_list.append(df) # inserindo o dataframe na lista de dataframes

# %%
data = reduce(lambda left,right: pd.merge(left,right,on=["year","period"]),data_list) # juntando os dataframes da lista

# %% [markdown]
# **Modifying the data and the dataframe index:**

# %%
df_data = data.iloc[::-1].reset_index().drop("index",axis=1) # invertendo os dados.

# %%
df_data["month"] = df_data["period"].apply(lambda x: x[1:]) # adicionando o mês.
df_data["day"] = (df_data["month"]!="").astype(int) # adicionando um dia falso com 1o.

# %%
index = pd.to_datetime(df_data[["year","month","day"]]).dt.strftime('%Y-%m') # criando datetime index.
df_data.index = index # trocado o index do dataframe
data = df_data.drop(["month","day","year","period"],axis=1).astype(float) # criando dados finais.
data.index = pd.to_datetime(data.index)
data.tail(5)
# Out:
#             All items  All items less food and energy     Food   Energy  \
# 2022-03-01    287.708                         288.811  295.809  305.469
# 2022-04-01    288.663                         290.455  298.379  297.233
# 2022-05-01    291.474                         292.289  301.879  308.839
# 2022-06-01    295.328                         294.354  304.867  332.087
# 2022-07-01    295.271                         295.275  308.220  316.955
#
#             Apparel  Education and communication  Other goods and services  \
# 2022-03-01  127.044                      143.680                   498.538
# 2022-04-01  126.087                      143.439                   500.673
# 2022-05-01  126.927                      143.363                   502.966
# 2022-06-01  127.929                      143.601                   505.312
# 2022-07-01  127.818                      143.356                   507.204
#
#             Medical care  Recreation  Transportation
# 2022-03-01       538.665     129.282         266.004
# 2022-04-01       541.057     129.830         264.995
# 2022-05-01       543.220     130.304         270.297
# 2022-06-01       546.861     130.687         280.691
# 2022-07-01       549.282     131.107         274.821

# %%
index_series = data.copy()

# %% [markdown]
# **Inflation YoY:**

# %%
df = (index_series.resample("Y").last().pct_change()*100).dropna().round(decimals=2)
df.index = df.index.year
df_t = df.T
df_t =  df_t.sort_values(by=2022)

bls_table = df_t.style.background_gradient().set_table_styles([{'selector': 'th', 'props': [('font-size', '18px')]},
                                     {'selector': 'td', 'props': [('font-size', '16px')]}]).format(precision=2)
bls_table
# Out:
# <style type="text/css">
# #T_0a133_ th {
#   font-size: 18px;
# }
# #T_0a133_ td {
#   font-size: 16px;
# }
# #T_0a133_row0_col0 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_0a133_row0_col1, #T_0a133_row0_col2, #T_0a133_row0_col6, #T_0a133_row0_col7, #T_0a133_row1_col4, #T_0a133_row9_col0, #T_0a133_row9_col3, #T_0a133_row9_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0a133_row0_col3 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_0a133_row0_col4 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_0a133_row0_col5 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_0a133_row1_col0, #T_0a133_row3_col1 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_0a133_row1_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_0a133_row1_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_0a133_row1_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_0a133_row1_col5 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_0a133_row1_col6 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_0a133_row1_col7 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_0a133_row2_col0, #T_0a133_row6_col0 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_0a133_row2_col1, #T_0a133_row3_col7 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_0a133_row2_col2, #T_0a133_row7_col7 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_0a133_row2_col3 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_0a133_row2_col4 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_0a133_row2_col5 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_0a133_row2_col6 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_0a133_row2_col7 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_0a133_row3_col0, #T_0a133_row3_col4, #T_0a133_row4_col3, #T_0a133_row7_col5, #T_0a133_row9_col1, #T_0a133_row9_col2, #T_0a133_row9_col6, #T_0a133_row9_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0a133_row3_col2, #T_0a133_row4_col2 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_0a133_row3_col3 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_0a133_row3_col5 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_0a133_row3_col6 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_0a133_row4_col0, #T_0a133_row5_col3 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_0a133_row4_col1 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_0a133_row4_col4 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_0a133_row4_col5, #T_0a133_row9_col4 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_0a133_row4_col6 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_0a133_row4_col7 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_0a133_row5_col0 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_0a133_row5_col1 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_0a133_row5_col2 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_0a133_row5_col4 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_0a133_row5_col5 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_0a133_row5_col6 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_0a133_row5_col7 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_0a133_row6_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_0a133_row6_col2, #T_0a133_row8_col3 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_0a133_row6_col3 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_0a133_row6_col4, #T_0a133_row8_col2 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_0a133_row6_col5 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_0a133_row6_col6 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_0a133_row6_col7 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_0a133_row7_col0 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_0a133_row7_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_0a133_row7_col2 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_0a133_row7_col3 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_0a133_row7_col4 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_0a133_row7_col6 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_0a133_row8_col0 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_0a133_row8_col1 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_0a133_row8_col4 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_0a133_row8_col5 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_0a133_row8_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_0a133_row8_col7 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0a133_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >2015</th>
#       <th class="col_heading level0 col1" >2016</th>
#       <th class="col_heading level0 col2" >2017</th>
#       <th class="col_heading level0 col3" >2018</th>
#       <th class="col_heading level0 col4" >2019</th>
#       <th class="col_heading level0 col5" >2020</th>
#       <th class="col_heading level0 col6" >2021</th>
#       <th class="col_heading level0 col7" >2022</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a133_level0_row0" class="row_heading level0 row0" >Education and communication</th>
#       <td id="T_0a133_row0_col0" class="data row0 col0" >1.39</td>
#       <td id="T_0a133_row0_col1" class="data row0 col1" >-0.23</td>
#       <td id="T_0a133_row0_col2" class="data row0 col2" >-1.74</td>
#       <td id="T_0a133_row0_col3" class="data row0 col3" >0.23</td>
#       <td id="T_0a133_row0_col4" class="data row0 col4" >1.37</td>
#       <td id="T_0a133_row0_col5" class="data row0 col5" >1.97</td>
#       <td id="T_0a133_row0_col6" class="data row0 col6" >1.63</td>
#       <td id="T_0a133_row0_col7" class="data row0 col7" >-0.27</td>
#     </tr>
#     <tr>
#       <th id="T_0a133_level0_row1" class="row_heading level0 row1" >Apparel</th>
#       <td id="T_0a133_row1_col0" class="data row1 col0" >-0.47</td>
#       <td id="T_0a133_row1_col1" class="data row1 col1" >0.11</td>
#       <td id="T_0a133_row1_col2" class="data row1 col2" >-1.55</td>
#       <td id="T_0a133_row1_col3" class="data row1 col3" >-0.08</td>
#       <td id="T_0a133_row1_col4" class="data row1 col4" >-1.30</td>
#       <td id="T_0a133_row1_col5" class="data row1 col5" >-4.17</td>
#       <td id="T_0a133_row1_col6" class="data row1 col6" >5.71</td>
#       <td id="T_0a133_row1_col7" class="data row1 col7" >2.98</td>
#     </tr>
#     <tr>
#       <th id="T_0a133_level0_row2" class="row_heading level0 row2" >Recreation</th>
#       <td id="T_0a133_row2_col0" class="data row2 col0" >0.64</td>
#       <td id="T_0a133_row2_col1" class="data row2 col1" >0.68</td>
#       <td id="T_0a133_row2_col2" class="data row2 col2" >1.47</td>
#       <td id="T_0a133_row2_col3" class="data row2 col3" >1.09</td>
#       <td id="T_0a133_row2_col4" class="data row2 col4" >1.49</td>
#       <td id="T_0a133_row2_col5" class="data row2 col5" >0.94</td>
#       <td id="T_0a133_row2_col6" class="data row2 col6" >3.27</td>
#       <td id="T_0a133_row2_col7" class="data row2 col7" >3.30</td>
#     </tr>
#     <tr>
#       <th id="T_0a133_level0_row3" class="row_heading level0 row3" >Medical care</th>
#       <td id="T_0a133_row3_col0" class="data row3 col0" >2.55</td>
#       <td id="T_0a133_row3_col1" class="data row3 col1" >3.93</td>
#       <td id="T_0a133_row3_col2" class="data row3 col2" >1.77</td>
#       <td id="T_0a133_row3_col3" class="data row3 col3" >2.02</td>
#       <td id="T_0a133_row3_col4" class="data row3 col4" >4.57</td>
#       <td id="T_0a133_row3_col5" class="data row3 col5" >1.78</td>
#       <td id="T_0a133_row3_col6" class="data row3 col6" >2.17</td>
#       <td id="T_0a133_row3_col7" class="data row3 col7" >3.39</td>
#     </tr>
#     <tr>
#       <th id="T_0a133_level0_row4" class="row_heading level0 row4" >All items less food and energy</th>
#       <td id="T_0a133_row4_col0" class="data row4 col0" >2.07</td>
#       <td id="T_0a133_row4_col1" class="data row4 col1" >2.20</td>
#       <td id="T_0a133_row4_col2" class="data row4 col2" >1.77</td>
#       <td i

# %% [markdown]
# **Saving:**

# %%
dataframe_image.export(bls_table,"Images/BLS Inflation Table.png")

# %% [markdown]
# ### World Equity Indices:

# %%
eq_indices  =   {"US (S&P500)":"^GSPC","US (Dow Jones)":"^DJI",  "US (Nasdaq)":"^IXIC", "US (NYSE composite)":"^NYA",
                 "UK (CBOE BUK 100)":"^BUK100P", "UK (FTSE)":"^FTSE","Germany (DAX)":"^GDAXI","France (CAC)":"^FCHI", 
                 "Europe (Euronext)":"^N100","Singapore (STI)":"^STI","Australia (ASX)":"^AXJO", 
                 "Indonesia (Jakarta Composite)":"^JKSE","Malaysia (Bursa)":"^KLSE","South Korea (Kospi)":"^KS11",
                 "Brazil (IBOV)":"^BVSP","Argentina (Merval)":"^MERV","China (Shanghai)":"000001.SS",
                 "China (Shenzhen)":"399001.SZ", "Belgium (Bel 200)":"^BFX","Japan (Nikkei)":"^N225",
                 "Russia (MOEX)":"IMOEX.ME","Hong Kong (Hang Seng)":"^HSI"}

# %%
equity_data = pd.DataFrame()
for key, value in eq_indices.items():
    try:
        equity_data[key] = pdr.DataReader(value, data_source = "yahoo", start=2010)["Close"]
    except:
        print("Error in: ", key)
# Out:
# Error in:  UK (FTSE)
# Error in:  Singapore (STI)
# Error in:  Malaysia (Bursa)

# %%
equity_tab = (equity_data.resample("Y").last().pct_change().dropna(how="all")*100).round(2)
equity_tab.index = equity_tab.index.year
equity_table = equity_tab.T.copy()
equity_table =  equity_table.sort_values(by=2022)
eq_table = equity_table.style.background_gradient().set_table_styles([{'selector': 'th', 'props': [('font-size', '18px')]},
                                                 {'selector': 'td', 'props': [('font-size', '16px')]}]).format(precision=2)
eq_table
# Out:
# <style type="text/css">
# #T_a36d9_ th {
#   font-size: 18px;
# }
# #T_a36d9_ td {
#   font-size: 16px;
# }
# #T_a36d9_row0_col0, #T_a36d9_row0_col1, #T_a36d9_row0_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a36d9_row0_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a36d9_row0_col4 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_a36d9_row0_col5 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_a36d9_row0_col6, #T_a36d9_row0_col11, #T_a36d9_row2_col1, #T_a36d9_row2_col5, #T_a36d9_row2_col7, #T_a36d9_row3_col3, #T_a36d9_row4_col10, #T_a36d9_row15_col9, #T_a36d9_row16_col2, #T_a36d9_row16_col4, #T_a36d9_row17_col8, #T_a36d9_row18_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a36d9_row0_col7, #T_a36d9_row17_col0 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_a36d9_row0_col8, #T_a36d9_row17_col7 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_a36d9_row0_col9, #T_a36d9_row0_col10 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_a36d9_row1_col0 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_a36d9_row1_col1, #T_a36d9_row18_col1 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_a36d9_row1_col2 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_a36d9_row1_col3, #T_a36d9_row1_col11, #T_a36d9_row4_col0, #T_a36d9_row15_col2 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_a36d9_row1_col4, #T_a36d9_row11_col11 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_a36d9_row1_col5, #T_a36d9_row4_col7, #T_a36d9_row10_col10 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_a36d9_row1_col6 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_a36d9_row1_col7 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_a36d9_row1_col8 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_a36d9_row1_col9, #T_a36d9_row2_col8, #T_a36d9_row5_col1, #T_a36d9_row11_col0, #T_a36d9_row16_col7, #T_a36d9_row18_col2, #T_a36d9_row18_col3, #T_a36d9_row18_col4, #T_a36d9_row18_col5, #T_a36d9_row18_col6, #T_a36d9_row18_col10, #T_a36d9_row18_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a36d9_row1_col10, #T_a36d9_row8_col4, #T_a36d9_row9_col1, #T_a36d9_row9_col4 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_a36d9_row2_col0, #T_a36d9_row2_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_a36d9_row2_col3 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_a36d9_row2_col4 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_a36d9_row2_col6 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_a36d9_row2_col9 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_a36d9_row2_col10, #T_a36d9_row5_col6, #T_a36d9_row13_col9 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_a36d9_row2_col11, #T_a36d9_row13_col2 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_a36d9_row3_col0 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_a36d9_row3_col1, #T_a36d9_row6_col3 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_a36d9_row3_col2, #T_a36d9_row17_col9 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_a36d9_row3_col4, #T_a36d9_row5_col11, #T_a36d9_row10_col9 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_a36d9_row3_col5, #T_a36d9_row14_col0 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_a36d9_row3_col6 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_a36d9_row3_col7, #T_a36d9_row6_col11, #T_a36d9_row15_col10 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_a36d9_row3_col8 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_a36d9_row3_col9 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_a36d9_row3_col10 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_a36d9_row3_col11, #T_a36d9_row14_col6 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_a36d9_row4_col1, #T_a36d9_row14_col1 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_a36d9_row4_col2, #T_a36d9_row9_col6, #T_a36d9_row15_col4 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_a36d9_row4_col3, #T_a36d9_row6_col9 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_a36d9_row4_col4 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_a36d9_row4_col5, #T_a36d9_row14_col5 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_a36d9_row4_col6 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_a36d9_row4_col8, #T_a36d9_row15_col6 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_a36d9_row4_col9, #T_a36d9_row14_col3 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_a36d9_row4_col11, #T_a36d9_row17_col10 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_a36d9_row5_col0, #T_a36d9_row7_col2 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_a36d9_row5_col2, #T_a36d9_row16_col6 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_a36d9_row5_col3, #T_a36d9_row8_col5 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_a36d9_row5_col4 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_a36d9_row5_col5, #T_a36d9_row13_col5 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_a36d9_row5_col7, #T_a36d9_row6_col2, #T_a36d9_row9_col2 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_a36d9_row5_col8, #T_a36d9_row13_col7 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_a36d9_row5_col9, #T_a36d9_row7_col6 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_a36d9_row5_col10, #T_a36d9_row12_col11, #T_a36d9_row13_col8, #T_a36d9_row14_col8 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_a36d9_row6_col0, #T_a36d9_row16_col9 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_a36d9_row6_col1 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_a36d9_row6_col4, #T_a36d9_row12_col8 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_a36d9_row6_col5, #T_a36d9_row7_col3 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_a36d9_row6_col6, #T_a36d9_row11_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_a36d9_row6_col7 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_a36d9_row6_col8 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_a36d9_row6_col10 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_a36d9_row7_col0, #T_a36d9_row18_col8 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_a36d9_row7_col1 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_a36d9_row7_col4 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_a36d9_row7_col5, #T_a36d9_row12_col1, #T_a36d9_row14_col4, #T_a36d9_row14_col7, #T_a36d9_row14_col11 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_a36d9_row7_col7 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_a36d9_row7_col8, #T_a36d9_row18_col9 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_a36d9_row7_col9 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_a36d9_row7_col10 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_a36d9_row7_col11 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_a36d9_row8_col0 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_a36d9_row8_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_a36d9_row8_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_a36d9_row8_col3 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_a36d9_row8_col6, #T_a36d9_row13_col6, #T_a36d9_row15_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_a36d9_row8_col7 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_a36d9_row8_col8, #T_a36d9_row10_col8, #T_a36d9_row11_col8, #T_a36d9_row12_col10 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_a36d9_row8_col9, #T_a36d9_row13_col1, #T_a36d9_row15_col11 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_a36d9_row8_col10 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_a36d9_row8_col11, #T_a36d9_row13_col10 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_a36d9_row9_col0 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_a36d9_row9_col3 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_a36d9_row9_col5 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_a36d9_row9_col7 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_a36d9_row9_col8, #T_a36d9_row11_col7 {
#   background-color: #4a98c5;
#   color:

# %% [markdown]
# **Saving:**

# %%
dataframe_image.export(eq_table,"Images/Equity Indices Table.png")

# %% [markdown]
# ### FX Rates:

# %%
fx_tickers = {"Brazil (USD/BRL)":"USDBRL=X","Canada (USD/CAD)":"USDCAD=X","Argentina (USD/ARG)":"USDARG=X",
              "India (USD/INR)":"USDINR=X","Colombia (USD/COP)":"USDCOP=X","Sweden (USD/SEK)":"USDSEK=X",
              "Europe (USD/EUR)":"USDEUR=X","England (USD/GBP)":"USDGBP=X"}

# %%
fx_data = pd.DataFrame()
for key, value in fx_tickers.items():
    try:
        fx_data[key] = pdr.DataReader(value, data_source = "yahoo", start=2010)["Close"]
    except:
        print("Error in: ", key)
# Out:
# Error in:  Argentina (USD/ARG)

# %%
fx_tab = (fx_data.resample("Y").last().pct_change().dropna(how="all")*100).round(2)
fx_tab.index = fx_tab.index.year
fx_table = fx_tab.T.copy()
fx_table =  fx_table.sort_values(by=2022)
currency_usd_table = fx_table.style.background_gradient().set_table_styles([{'selector': 'th', 
                  'props': [('font-size', '18px')]}, {'selector': 'td', 'props': [('font-size', '16px')]}]).format(precision=2)
currency_usd_table
# Out:
# <style type="text/css">
# #T_4b666_ th {
#   font-size: 18px;
# }
# #T_4b666_ td {
#   font-size: 16px;
# }
# #T_4b666_row0_col0, #T_4b666_row6_col5 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_4b666_row0_col1, #T_4b666_row0_col2, #T_4b666_row0_col4, #T_4b666_row0_col6, #T_4b666_row0_col7, #T_4b666_row0_col9, #T_4b666_row2_col3, #T_4b666_row2_col10, #T_4b666_row3_col0, #T_4b666_row5_col5, #T_4b666_row6_col8, #T_4b666_row6_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_4b666_row0_col3 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_4b666_row0_col5, #T_4b666_row0_col11, #T_4b666_row1_col8, #T_4b666_row1_col10, #T_4b666_row2_col1, #T_4b666_row3_col3, #T_4b666_row3_col4, #T_4b666_row4_col2, #T_4b666_row4_col6, #T_4b666_row4_col7, #T_4b666_row5_col0, #T_4b666_row6_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_4b666_row0_col8 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_4b666_row0_col10, #T_4b666_row1_col5 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_4b666_row1_col0, #T_4b666_row6_col0 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_4b666_row1_col1 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_4b666_row1_col2 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_4b666_row1_col3 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_4b666_row1_col4 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_4b666_row1_col6 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_4b666_row1_col7, #T_4b666_row2_col5 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_4b666_row1_col9 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_4b666_row1_col11, #T_4b666_row4_col10 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_4b666_row2_col0, #T_4b666_row5_col10 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_4b666_row2_col2 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_4b666_row2_col4 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_4b666_row2_col6 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_4b666_row2_col7 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_4b666_row2_col8 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_4b666_row2_col9 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_4b666_row2_col11, #T_4b666_row4_col5, #T_4b666_row6_col10 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_4b666_row3_col1 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_4b666_row3_col2 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_4b666_row3_col5 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_4b666_row3_col6 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_4b666_row3_col7 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_4b666_row3_col8 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_4b666_row3_col9, #T_4b666_row6_col7 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_4b666_row3_col10 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_4b666_row3_col11 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_4b666_row4_col0 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_4b666_row4_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_4b666_row4_col3 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_4b666_row4_col4 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_4b666_row4_col8 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_4b666_row4_col9 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_4b666_row4_col11 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_4b666_row5_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_4b666_row5_col2, #T_4b666_row5_col8 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_4b666_row5_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_4b666_row5_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_4b666_row5_col6 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_4b666_row5_col7 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_4b666_row5_col9 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_4b666_row5_col11 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_4b666_row6_col1 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_4b666_row6_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_4b666_row6_col3 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_4b666_row6_col4 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_4b666_row6_col6 {
#   background-color: #e0dded;
#   color: #000000;
# }
# </style>
# <table id="T_4b666_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="col_heading level0 col0" >2011</th>
#       <th class="col_heading level0 col1" >2012</th>
#       <th class="col_heading level0 col2" >2013</th>
#       <th class="col_heading level0 col3" >2014</th>
#       <th class="col_heading level0 col4" >2015</th>
#       <th class="col_heading level0 col5" >2016</th>
#       <th class="col_heading level0 col6" >2017</th>
#       <th class="col_heading level0 col7" >2018</th>
#       <th class="col_heading level0 col8" >2019</th>
#       <th class="col_heading level0 col9" >2020</th>
#       <th class="col_heading level0 col10" >2021</th>
#       <th class="col_heading level0 col11" >2022</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b666_level0_row0" class="row_heading level0 row0" >Brazil (USD/BRL)</th>
#       <td id="T_4b666_row0_col0" class="data row0 col0" >12.23</td>
#       <td id="T_4b666_row0_col1" class="data row0 col1" >9.65</td>
#       <td id="T_4b666_row0_col2" class="data row0 col2" >15.36</td>
#       <td id="T_4b666_row0_col3" class="data row0 col3" >12.50</td>
#       <td id="T_4b666_row0_col4" class="data row0 col4" >49.08</td>
#       <td id="T_4b666_row0_col5" class="data row0 col5" >-17.80</td>
#       <td id="T_4b666_row0_col6" class="data row0 col6" >1.81</td>
#       <td id="T_4b666_row0_col7" class="data row0 col7" >17.01</td>
#       <td id="T_4b666_row0_col8" class="data row0 col8" >3.65</td>
#       <td id="T_4b666_row0_col9" class="data row0 col9" >29.26</td>
#       <td id="T_4b666_row0_col10" class="data row0 col10" >7.31</td>
#       <td id="T_4b666_row0_col11" class="data row0 col11" >-8.96</td>
#     </tr>
#     <tr>
#       <th id="T_4b666_level0_row1" class="row_heading level0 row1" >Canada (USD/CAD)</th>
#       <td id="T_4b666_row1_col0" class="data row1 col0" >2.07</td>
#       <td id="T_4b666_row1_col1" class="data row1 col1" >-2.54</td>
#       <td id="T_4b666_row1_col2" class="data row1 col2" >7.05</td>
#       <td id="T_4b666_row1_col3" class="data row1 col3" >9.02</td>
#       <td id="T_4b666_row1_col4" class="data row1 col4" >19.54</td>
#       <td id="T_4b666_row1_col5" class="data row1 col5" >-2.84</td>
#       <td id="T_4b666_row1_col6" class="data row1 col6" >-6.77</td>
#       <td id="T_4b666_row1_col7" class="data row1 col7" >8.41</td>
#       <td id="T_4b666_row1_col8" class="data row1 col8" >-4.12</td>
#       <td id="T_4b666_row1_col9" class="data row1 col9" >-2.37</td>
#       <td id="T_4b666_row1_col10" class="data row1 col10" >-0.05</td>
#       <td id="T_4b666_row1_col11" class="data row1 col11" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_4b666_level0_row2" class="row_heading level0 row2" >Colombia (USD/COP)</th>
#       <td id="T_4b666_row2_col0" class="data row2 col0" >1.10</td>
#       <td id="T_4b666_row2_col1" class="data row2 col1" >-8.78</td>
#       <td id="T_4b666_row2_col2" class="data row2 col2" >9.23</td>
#       <td id="T_4b666_row2_col3" class="data row2 col3" >23.12</td>
#       <td id="T_4b666_row2_col4" class="data row2 col4" >32.13</td>
#       <td id="T_4b666_row2_col5" class="data row2 col5" >-5.52</td>
#       <td id="T_4b666_row2_col6" class="data row2 col6" >0.58</td>
#       <td id="T_4b666_row2_col7" class="data row2 col7" >8.82</td>
#       <td id="T_4b666_row2_col8" class="data row2 col8" >1.17</td>
#       <td id="T_4b666_row2_col9" class="data row2 col9" >4.18</td>
#       <td id="T_4b666_row2_col10" class="data row2 col10" >18.95</td>
#       <td id="T_4b666_row2_col11" class="data row2 col11" >2.16</td>
#     </tr>
#     <tr>
#       <th id="T_4b666_level0_row3" class="row_heading level0

# %% [markdown]
# **Saving:**

# %%
dataframe_image.export(currency_usd_table,"Images/FX Table.png")

# %% [markdown]
# ### Commodities (Futures):

# %%
commodities_tickers ={"Gold":"GC=F", "Silver":"SI=F","Crude Oil":"CL=F","Corn":"ZC=F","Oat":"ZO=F","Soybeans":"ZS=F",
                      "Live Cattle":"LE=F", "Cocoa":"CC=F", "Coffee":"KC=F", "Cotton":"CT=F", "Orange Juice":"OJ=F",
                      "Sugar":"SB=F","Natural Gas":"NG=F","Platinum":"PL=F","Copper":"HG=F","Palladium":"PA=F",
                     "Heating Oil":"HO=F", "Lean Hogs":"HE=F","Lumber":"LBS=F","Rough Rice":"ZR=F","Wheat":"KE=F"}

# %%
commodities_data = pd.DataFrame()
for key, value in commodities_tickers.items():
    try:
        commodities_data[key] = pdr.DataReader(value, data_source = "yahoo", start="2010",end="2022-07-22")["Close"]
    except:
        print("Error in: ", key)

# %%
commodities_tab = (commodities_data.resample("Y").last().pct_change().dropna(how="all")*100).round(2)
commodities_tab.index = commodities_tab.index.year
commodities_table = commodities_tab.T.copy()
commodities_table =  commodities_table.sort_values(by=2022)
comm_table = commodities_table.style.background_gradient().set_table_styles([{'selector': 'th', 'props': [('font-size', '18px')]},
                                                 {'selector': 'td', 'props': [('font-size', '16px')]}]).format(precision=2)
comm_table
# Out:
# <style type="text/css">
# #T_bef70_ th {
#   font-size: 18px;
# }
# #T_bef70_ td {
#   font-size: 16px;
# }
# #T_bef70_row0_col0, #T_bef70_row5_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_bef70_row0_col1, #T_bef70_row0_col9, #T_bef70_row1_col10, #T_bef70_row6_col4, #T_bef70_row6_col7, #T_bef70_row7_col3, #T_bef70_row14_col6, #T_bef70_row14_col8, #T_bef70_row19_col0, #T_bef70_row20_col2, #T_bef70_row20_col5, #T_bef70_row20_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bef70_row0_col2 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_bef70_row0_col3, #T_bef70_row6_col8 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_bef70_row0_col4, #T_bef70_row1_col9, #T_bef70_row9_col3 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_bef70_row0_col5, #T_bef70_row10_col4 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_bef70_row0_col6 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_bef70_row0_col7, #T_bef70_row0_col11, #T_bef70_row4_col0, #T_bef70_row6_col5, #T_bef70_row7_col1, #T_bef70_row9_col6, #T_bef70_row10_col2, #T_bef70_row14_col10, #T_bef70_row17_col3, #T_bef70_row19_col4, #T_bef70_row19_col9, #T_bef70_row20_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bef70_row0_col8, #T_bef70_row5_col8, #T_bef70_row10_col7 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_bef70_row0_col10, #T_bef70_row11_col1 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_bef70_row1_col0 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_bef70_row1_col1 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_bef70_row1_col2 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_bef70_row1_col3, #T_bef70_row5_col6, #T_bef70_row11_col8 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_bef70_row1_col4, #T_bef70_row7_col11 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_bef70_row1_col5, #T_bef70_row20_col4 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_bef70_row1_col6, #T_bef70_row14_col0 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_bef70_row1_col7 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_bef70_row1_col8, #T_bef70_row2_col8 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_bef70_row1_col11, #T_bef70_row20_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_bef70_row2_col0, #T_bef70_row5_col9 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_bef70_row2_col1, #T_bef70_row4_col5, #T_bef70_row6_col1, #T_bef70_row15_col2 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_bef70_row2_col2, #T_bef70_row15_col5 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_bef70_row2_col3 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_bef70_row2_col4, #T_bef70_row3_col7, #T_bef70_row20_col9 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_bef70_row2_col5, #T_bef70_row18_col8 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_bef70_row2_col6 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_bef70_row2_col7 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_bef70_row2_col9, #T_bef70_row5_col5, #T_bef70_row10_col8, #T_bef70_row16_col11 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_bef70_row2_col10, #T_bef70_row11_col4 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_bef70_row2_col11, #T_bef70_row6_col6 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_bef70_row3_col0 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_bef70_row3_col1, #T_bef70_row11_col7, #T_bef70_row15_col4 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_bef70_row3_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_bef70_row3_col3, #T_bef70_row10_col6, #T_bef70_row18_col4 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_bef70_row3_col4, #T_bef70_row19_col11 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_bef70_row3_col5, #T_bef70_row3_col8, #T_bef70_row5_col1 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_bef70_row3_col6 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_bef70_row3_col9 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_bef70_row3_col10, #T_bef70_row9_col7 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_bef70_row3_col11, #T_bef70_row8_col10 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_bef70_row4_col1, #T_bef70_row6_col9, #T_bef70_row14_col4, #T_bef70_row15_col10 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_bef70_row4_col2, #T_bef70_row14_col7 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_bef70_row4_col3, #T_bef70_row9_col0, #T_bef70_row18_col9 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_bef70_row4_col4 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_bef70_row4_col6, #T_bef70_row18_col3 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_bef70_row4_col7 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_bef70_row4_col8 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_bef70_row4_col9 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_bef70_row4_col10, #T_bef70_row7_col0, #T_bef70_row12_col1, #T_bef70_row14_col5, #T_bef70_row18_col2, #T_bef70_row19_col8 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_bef70_row4_col11 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_bef70_row5_col0, #T_bef70_row9_col9, #T_bef70_row12_col4, #T_bef70_row12_col11 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_bef70_row5_col2, #T_bef70_row15_col0, #T_bef70_row16_col1, #T_bef70_row17_col6, #T_bef70_row17_col11, #T_bef70_row18_col1 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_bef70_row5_col4, #T_bef70_row11_col11 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_bef70_row5_col7, #T_bef70_row16_col3 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_bef70_row5_col10 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_bef70_row5_col11, #T_bef70_row15_col6 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_bef70_row6_col0 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_bef70_row6_col2 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_bef70_row6_col3, #T_bef70_row18_col11, #T_bef70_row19_col6, #T_bef70_row20_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_bef70_row6_col10 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_bef70_row6_col11, #T_bef70_row9_col1 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_bef70_row7_col2, #T_bef70_row8_col11, #T_bef70_row12_col2 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_bef70_row7_col4, #T_bef70_row11_col6, #T_bef70_row12_col8 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_bef70_row7_col5, #T_bef70_row8_col6 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_bef70_row7_col6, #T_bef70_row7_col9 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_bef70_row7_col7, #T_bef70_row11_col9 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_bef70_row7_col8 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_bef70_row7_col10 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_bef70_row8_col0 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_bef70_row8_col1, #T_bef70_row12_col10 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_bef70_row8_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_bef70_row8_col3, #T_bef70_row19_col1 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_bef70_row8_col4, #T_bef70_row14_col3, #T_bef70_row16_col6 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_bef70_row8_col5, #T_bef70_row12_col3 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_bef70_row8_col7 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_bef70_row8_col8 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_bef70_row8_col9, #T_bef70_row9_col2, #T_bef70_row12_col9, #T_bef70_row16_col10 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_bef70_row9_col4 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_bef70_row9_col5 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_bef70_row9_col8, #T_bef70_row18_col5 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_bef70_row9_col10 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_bef70_row9_col11, #T_bef70

# %% [markdown]
# **Saving:**

# %%
dataframe_image.export(comm_table,"Images/Commodities Table.png")

# %% [markdown]
# **Adding the Tables to a PDF document:**

# %% [markdown]
# - **BLS Inflation:**

# %%
pdf = fpdf.FPDF()
pdf.add_page()
pdf.set_font("Times", "B", 14)
today = str(datetime.datetime.today().strftime('%Y-%m-%d'))
pdf.cell(1, 3, today, align='L')
pdf.set_font("Times", "B", 16)
pdf.cell(0, 30, 'BLS US Inflation Data',align = "C")
pdf.image('Images/BLS Inflation Table.png', x = 30, y = 40, h=75, w=150)
pdf.output("Report Drafts/BLS Inflation.pdf","F")
# Out:
# ''

# %% [markdown]
# - **World Equity Indices:**

# %%
pdf = fpdf.FPDF()
pdf.add_page()
pdf.set_font("Times", "B", 14)
today = str(datetime.datetime.today().strftime('%Y-%m-%d'))
pdf.cell(1, 3, today, align='L')
pdf.set_font("Times", "B", 16)
pdf.cell(0, 30, 'World Equity Indices Data',align = "C")
pdf.image('Images/Equity Indices Table.png', x = 30, y = 40, w = 155, h=155)
pdf.output("Report Drafts/World Equity Indices.pdf","F")
pdf.add_page()

# %% [markdown]
# - **FX Table:**

# %%
pdf = fpdf.FPDF()
pdf.add_page()
pdf.set_font("Times", "B", 14)
today = str(datetime.datetime.today().strftime('%Y-%m-%d'))
pdf.cell(1, 3, today, align='L')
pdf.set_font("Times", "B", 16)
pdf.cell(0, 30, 'FX USD Data',align = "C")
pdf.image('Images/FX Table.png', x = 30, y = 40, w = 150, h=60)
pdf.output("Report Drafts/FX.pdf","F")
pdf.add_page()

# %% [markdown]
# - **Commodities:**

# %%
pdf = fpdf.FPDF()
pdf.add_page()
pdf.set_font("Times", "B", 14)
today = str(datetime.datetime.today().strftime('%Y-%m-%d'))
pdf.cell(1, 3, today, align='L')
pdf.set_font("Times", "B", 16)
pdf.cell(0, 30, 'Commodities Data',align = "C")
pdf.image('Images/Commodities Table.png', x = 30, y = 40, w = 150, h=150)
pdf.output("Report Drafts/Commodities.pdf","F")
pdf.add_page()

# %% [markdown]
# **Merging all PDF Files:**

# %%
merger = PdfFileMerger()
merger.append("Report Drafts/BLS Inflation.pdf")
merger.append("Report Drafts/World Equity Indices.pdf")
merger.append("Report Drafts/FX.pdf", 'rb')
merger.append("Report Drafts/Commodities.pdf", 'rb')
merger.write("Daily Macro Report - " + today + ".pdf")

# %% [markdown]
# **Sending E-mail with PDF Attachment:**

# %%
def SendMacroEmail(pdf_path, subject, destination_email, password):
    server = smtplib.SMTP('smtp.outlook.com', 587)
    server.starttls()
    server.login('market.automations@outlook.com', password)
    msg = MIMEMultipart()

    msg['Subject'] = subject
    msg['From'] = 'market.automations@outlook.com'
    msg['To'] = destination_email
    
    today = str(datetime.datetime.today().strftime('%Y-%m-%d'))
  
    with open(pdf_path, "rb") as f:
        attach = MIMEApplication(f.read(),_subtype="pdf")
        attach.add_header('Content-Disposition','attachment', filename=f"Macro Report - {today}")
        msg.attach(attach)
    server.send_message(msg)

# %%
SendMacroEmail("Daily Macro Report - " + today + ".pdf", f"Macro Report - {today}", "pedro.osoriomn@gmail.com", email_password)

# %% [markdown]
# **-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**
